# %% [markdown]
# <a href="https://colab.research.google.com/github/archana-verma/Reesa_Archana/blob/main/bcf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pandas as pd
import os
from matplotlib import image
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
def find_orbitals(filename):
  with open(filename, "r") as f:
    orbitals = []
    inner_orbitals = []
    parse = False
    for line in f:
      #start exctract text 
      if 'ORBITAL ENERGIES' in line:
        parse = True
        next(f)
        next(f)
        continue
                  
      if parse:
        if len(line.split()) == 0:
          orbitals.append(inner_orbitals)
          inner_orbitals = []
          break
        else:
          inner_orbitals.append(line)

  return orbitals[-1]

# %%
import pandas as pd

def Extract(i, lst):
  return [item[i] for item in lst]
  
def clean_data(filename):
  orbital_list = find_orbitals(filename)
  rows = []

  for x in range(1, len(orbital_list)):
    rows.append(orbital_list[x].split())

  data = np.array(rows)

  no = Extract(0, data)
  occ = Extract(1, data)
  eeh = Extract(2, data)
  eev = Extract(3, data)

  dict = {'NO': no, 'OCC': occ, 'E(Eh)': eeh, 'E(eV)': eev} 

  df = pd.DataFrame(dict) 
      

  return df

# %%
# !git clone https://github.com/archana-verma/Reesa_Archana.git
os.chdir('./Reesa_Archana/BCF')
# Out:
# Cloning into 'Reesa_Archana'...
# remote: Enumerating objects: 396, done.
# remote: Counting objects: 100% (208/208), done.
# remote: Compressing objects: 100% (200/200), done.
# remote: Total 396 (delta 75), reused 79 (delta 7), pack-reused 188
# Receiving objects: 100% (396/396), 96.08 MiB | 12.62 MiB/s, done.
# Resolving deltas: 100% (99/99), done.
# Updating files: 100% (253/253), done.

# %%
bcf = open('BCF.out', 'r')
bcf.readlines()
# Out:
# ['Warning: no access to tty (Bad file descriptor).\n',
#  'Thus no job control in this shell.\n',
#  '\n',
#  '                                 *****************\n',
#  '                                 * O   R   C   A *\n',
#  '                                 *****************\n',
#  '\n',
#  '           --- An Ab Initio, DFT and Semiempirical electronic structure package ---\n',
#  '\n',
#  '                  #######################################################\n',
#  '                  #                        -***-                        #\n',
#  '                  #          Department of theory and spectroscopy      #\n',
#  '                  #               Directorship: Frank Neese             #\n',
#  '                  #        Max Planck Institute fuer Kohlenforschung    #\n',
#  '                  #                Kaiser Wilhelm Platz 1               #\n',
#  '                  #                 D-45470 Muelheim/Ruhr               #\n',
#  '                  #                      Germany                        #\n',
#  '                  #                                                     #\n',
#  '                  #                  All rights reserved                #\n',
#  '                  #                        -***-                        #\n',
#  '                  #######################################################\n',
#  '\n',
#  '\n',
#  '                         Program Version 4.2.1 -  RELEASE  -\n',
#  '\n',
#  '\n',
#  ' With contributions from (in alphabetic order):\n',
#  '   Daniel Aravena         : Magnetic Suceptibility\n',
#  '   Michael Atanasov       : Ab Initio Ligand Field Theory (pilot matlab implementation)\n',
#  '   Alexander A. Auer      : GIAO ZORA, VPT2\n',
#  '   Ute Becker             : Parallelization\n',
#  '   Giovanni Bistoni       : ED, misc. LED, open-shell LED, HFLD\n',
#  '   Martin Brehm           : Molecular dynamics\n',
#  '   Dmytro Bykov           : SCF Hessian\n',
#  '   Vijay G. Chilkuri      : MRCI spin determinant printing, contributions to CSF-ICE\n',
#  '   Dipayan Datta          : RHF DLPNO-CCSD density\n',
#  '   Achintya Kumar Dutta   : EOM-CC, STEOM-CC\n',
#  '   Dmitry Ganyushin       : Spin-Orbit,Spin-Spin,Magnetic field MRCI\n',
#  '   Miquel Garcia          : C-PCM Hessian, Gaussian charge scheme\n',
#  '   Yang Guo               : DLPNO-NEVPT2, CIM, IAO-localization\n',
#  '   Andreas Hansen         : Spin unrestricted coupled pair/coupled cluster methods\n',
#  '   Benjamin Helmich-Paris : CASSCF linear response (MC-RPA)\n',
#  '   Lee Huntington         : MR-EOM, pCC\n',
#  '   Robert Izsak           : Overlap fitted RIJCOSX, COSX-SCS-MP3, EOM\n',
#  '   Christian Kollmar      : KDIIS, OOCD, Brueckner-CCSD(T), CCSD density\n',
#  '   Simone Kossmann        : Meta GGA functionals, TD-DFT gradient, OOMP2, MP2 Hessian\n',
#  '   Martin Krupicka        : AUTO-CI\n',
#  '   Lucas Lang             : DCDCAS\n',
#  '   Dagmar Lenk            : GEPOL surface, SMD\n',
#  '   Dimitrios Liakos       : Extrapolation schemes; Compound Job, initial MDCI parallelization\n',
#  '   Dimitrios Manganas     : Further ROCIS development; embedding schemes\n',
#  '   Dimitrios Pantazis     : SARC Basis sets\n',
#  '   Taras Petrenko         : DFT Hessian,TD-DFT gradient, ASA, ECA, R-Raman, ABS, FL, XAS/XES, NRVS\n',
#  '   Peter Pinski           : DLPNO-MP2, DLPNO-MP2 Gradient\n',
#  '   Christoph Reimann      : Effective Core Potentials\n',
#  '   Marius Retegan         : Local ZFS, SOC\n',
#  '   Christoph Riplinger    : Optimizer, TS searches, QM/MM, DLPNO-CCSD(T), (RO)-DLPNO pert. Triples\n',
#  '   Tobias Risthaus        : Range-separated hybrids, TD-DFT gradient, RPA, STAB\n',
#  '   Michael Roemelt        : Original ROCIS implementation\n',
#  '   Masaaki Saitow         : Open-shell DLPNO-CCSD energy and density\n',
#  '   Barbara Sandhoefer     : DKH picture change effects\n',
#  '   Avijit Sen             : IP-ROCIS\n',
#  '   Kantharuban Sivalingam : CASSCF convergence, NEVPT2, FIC-MRCI\n',
#  '   Bernardo de Souza      : ESD, SOC TD-DFT\n',
#  '   Georgi Stoychev        : AutoAux, RI-MP2 NMR\n',
#  '   Willem Van den Heuvel  : Paramagnetic NMR\n',
#  '   Boris Wezisla          : Elementary symmetry handling\n',
#  '   Frank Wennmohs         : Technical directorship\n',
#  '\n',
#  '\n',
#  ' We gratefully acknowledge several colleagues who have allowed us to\n',
#  ' interface, adapt or use parts of their codes:\n',
#  '   Stefan Grimme, W. Hujo, H. Kruse,             : VdW corrections, initial TS optimization,\n',
#  '                  C. Bannwarth                     DFT functionals, gCP, sTDA/sTD-DF\n',
#  '   Ed Valeev, F. Pavosevic, A. Kumar             : LibInt (2-el integral package), F12 methods\n',
#  '   Garnet Chan, S. Sharma, J. Yang, R. Olivares  : DMRG\n',
#  '   Ulf Ekstrom                                   : XCFun DFT Library\n',
#  '   Mihaly Kallay                                 : mrcc  (arbitrary order and MRCC methods)\n',
#  '   Andreas Klamt, Michael Diedenhofen            : otool_cosmo (COSMO solvation model)\n',
#  '   Jiri Pittner, Ondrej Demel                    : Mk-CCSD\n',
#  '   Frank Weinhold                                : gennbo (NPA and NBO analysis)\n',
#  '   Christopher J. Cramer and Donald G. Truhlar   : smd solvation model\n',
#  '   Lars Goerigk                                  : TD-DFT with DH, B97 family of functionals\n',
#  '   V. Asgeirsson, H. Jonsson                     : NEB implementation\n',
#  '   FAccTs GmbH                                   : IRC, NEB, NEB-TS, Multilevel, MM, QM/MM, CI optimization\n',
#  '   S Lehtola, MJT Oliveira, MAL Marques          : LibXC Library\n',
#  '\n',
#  '\n',
#  ' Your calculation uses the libint2 library for the computation of 2-el integrals\n',
#  ' For citations please refer to: http://libint.valeyev.net\n',
#  '\n',
#  ' Your ORCA version has been built with support for libXC version: 4.2.3\n',
#  ' For citations please refer to: https://tddft.org/programs/libxc/\n',
#  '\n',
#  ' This ORCA versions uses:\n',
#  '   CBLAS   interface :  Fast vector & matrix operations\n',
#  '   LAPACKE interface :  Fast linear algebra routines\n',
#  '   SCALAPACK package :  Parallel linear algebra routines\n',
#  '\n',
#  '\n',
#  'Your calculation utilizes the atom-pairwise dispersion correction\n',
#  'with the zero-damping scheme (D30)\n',
#  'Cite in your paper:\n',
#  'S.Grimme, J.Antony, S.Ehrlich and H.Krieg, J.Chem.Phys., 132, (2010), 154104 \n',
#  '   \n',
#  '\n',
#  'XCFun DFT library Copyright 2009-2010 Ulf Ekstrom and contributors.\n',
#  'See http://admol.org/xcfun for more information. This is free soft-\n',
#  'ware; see the source code for copying conditions. There is ABSOLUTELY\n',
#  'NO WARRANTY; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR\n',
#  'PURPOSE. For details see the documentation. Scientific users of this \n',
#  'library should cite U. Ekstrom, L. Visscher, R. Bast, A. J. Thorvald-\n',
#  'sen and K. Ruud; J.Chem.Theor.Comp. 2010, DOI: 10.1021/ct100117s\n',
#  'XCFun Version 0.99 \n',
#  '----- Orbital basis set information -----\n',
#  'Your calculation utilizes the basis: def2-TZVP\n',
#  '   F. Weigend and R. Ahlrichs, Phys. Chem. Chem. Phys. 7, 3297 (2005).\n',
#  '\n',
#  '----- AuxJ basis set information -----\n',
#  'Your calculation utilizes the auxiliary basis: def2/J\n',
#  '   F. Weigend, Phys. Chem. Chem. Phys. 8, 1057 (2006).\n',
#  '\n',
#  '================================================================================\n',
#  '                                        WARNINGS\n',
#  '                       Please study these warnings very carefully!\n',
#  '================================================================================\n',
#  '\n',
#  '\n',
#  'WARNING: Geometry Optimization\n',
#  '  ===> : Switching off AutoStart\n',
#  '         For restart on a previous wavefunction, please use MOREAD\n',
#  '\n',
#  'INFO   : the flag for use of LIBINT has been found!\n',
#  '\n',
#  '================================================================================\n',
#  '                                       INPUT FILE\n',
#  '================================================================================\n',
#  'NAME = BCF.inp\n',
#  '|  1> # avogadro generated ORCA input file \n',
#  '|  2> # Basic Mode\n',
#  '|  3> # \n',
#  '|  4> ! wB97X-D3 OPT def2-TZVP def2/J CPCM\n',
#  '|  5> %cpcm\n',
#  '|  6>   epsilon 3\n',
#  '|  7> end\n',
#  '|  8> %pal\n',
#  '|  9>  nprocs 4\n',
#  '| 10> end\n',
#  '| 11> \n',
#  '| 12> * xyz 0 1\n',
#  '| 13>    C       -0.38838        4.42479        0.19957\n',
#  '| 14>    C       -1.11716        3.23911        0.05784\n',
#  '| 15>    C       -0.81317        5.40989        1.09097\n',
#  '| 16>    C       -2.29477        3.02423        0.81172\n',
#  '| 17>    C       -1.97073        5.21518        1.84417\n',
#  '| 18>    C       -2.71079        4.03589        1.70902\n',
#  '| 19>    C       -2.38774        0.28635        0.31734\n',
#  '| 20>    C       -1.07394        0.04319        0.78305\n',
#  '| 21>    C       -0.42591       -1.16103        0.48842\n',
#  '| 22>    C       -3.02249       -0.71732       -0.45195\n',
#  '| 23>    C       -2.36189       -1.91582       -0.74217\n',
#  '| 24>    C       -1.06752       -2.13775       -0.27276\n',
#  '| 25>    F        0.73381        4.62073       -0.53685\n',
#  '| 26>    F       -0.68078        2.32388       -0.84491\n',
#  '| 27>    F       -0.10111        6.55647        1.22522\n',
#  '| 28>    F       -2.37707        6.17214        2.71549\n',
#  '| 29>    F       -3.81295        3.87997        2.48621\n',
#  '| 30>    F       -4.26898       -0.53605       -0.95815\n',
#  '| 31>    F       -2.98023       -2.86509       -1.48827\n',
#  '| 32>    F       -0.43309       -3.30259       -0.55629\n',
#  '| 33>    F        0.83039       -1.38310        0.94935\n',
#  '| 34>    F       -0.41929        0.94891        1.55377\n',
#  '| 35>    B       -3.13912        1.66667        0.65349\n',
#  '| 36>    C       -4.73562        1.69237        0.83209\n',
#  '| 37>    C       -5.48788        2.83183        0.46120\n',
#  '| 38>    C       -6.87785        2.84840        0.61714\n',
#  '| 39>    C       -5.42528        0.57762        1.36420\n',
#  '| 40>    C       -7.54007        1.74034        1.14518\n',
#  '| 41>    C       -6.81536        0.60862        1.51851\n',
#  '| 42>    F       -4.89299        3.92270       -0.08580\n',
#  '| 43>    F       -7.58646        3.94475        0.24840\n',
#  '| 44>    F       -4.76111       -0.53427        1.77105\n',
#  '| 45>    F       -7.46194       -0.46443        2.03867\n',
#  '| 46>    F       -8.88786        1.76346        1.29561\n',
#  '| 47> *\n',
#  '| 48> \n',
#  '| 49> \n',
#  '| 50>                          ****END OF INPUT****\n',
#  '================================================================================\n',
#  '\n',
#  '                       *****************************\n',
#  '                       * Geometry Optimization Run *\n',
#  '                       *****************************\n',
#  '\n',
#  'Geometry optimization settings:\n',
#  'Update method            Update   .... BFGS\n',
#  'Choice of coordinates    CoordSys .... Z-matrix Internals\n',
#  "Initial Hessian          InHess   .... Almoef's Model\n",
#  '\n',
#  'Convergence Tolerances:\n',
#  'Energy Change            TolE     ....  5.0000e-06 Eh\n',
#  'Max. Gradient            TolMAXG  ....  3.0000e-04 Eh/bohr\n',
#  'RMS Gradient             TolRMSG  ....  1.0000e-04 Eh/bohr\n',
#  'Max. Displacement        TolMAXD  ....  4.0000e-03 bohr\n',
#  'RMS Displacement         TolRMSD  ....  2.0000e-03 bohr\n',
#  'Strict Convergence                ....  False\n',
#  '------------------------------------------------------------------------------\n',
#  '                        ORCA OPTIMIZATION COORDINATE SETUP\n',
#  '------------------------------------------------------------------------------\n',
#  '\n',
#  'The optimization will be done in new redundant internal coordinates\n',
#  'Making redundant internal coordinates   ...  (new redundants) done\n',
#  'Evaluating the initial hessian          ...  (Almloef) done\n',
#  'Evaluating the coordinates              ...  done\n',
#  'Calculating the B-matrix                .... done\n',
#  'Calculating the G-matrix                .... done\n',
#  'Diagonalizing the G-matrix              .... done\n',
#  'Small eigenvalue found = 4.560e-03\n',
#  'Small eigenvalue found = 4.570e-03\n',
#  'Small eigenvalue found = 1.947e-02\n',
#  'Small eigenvalue found = 2.915e-02\n',
#  'Small eigenvalue found = 2.930e-02\n',
#  'The first mode is                       ....   81\n',
#  'The number of degrees of freedom        ....   96\n',
#  '\n',
#  '    -----------------------------------------------------------------\n',
#  '                    Redundant Internal Coordinates\n',
#  '\n',
#  '\n',
#  '    -----------------------------------------------------------------\n',
#  '         Definition                    Initial Value    Approx d2E/dq\n',
#  '    -----------------------------------------------------------------\n',
#  '      1. B(C   1,C   0)                  1.3989         0.604601   \n',
#  '      2. B(C   2,C   0)                  1.3948         0.613879   \n',
#  '      3. B(C   3,C   1)                  1.4147         0.570675   \n',
#  '      4. B(C   4,C   2)                  1.3947         0.614118   \n',
#  '      5. B(C   5,C   4)                  1.3988         0.604891   \n',
#  '      6. B(C   5,C   3)                  1.4148         0.570377   \n',
#  '      7. B(C   7,C   6)                  1.4149         0.570076   \n',
#  '      8. B(C   8,C   7)                  1.3989         0.604719   \n',
#  '      9. B(C   9,C   6)                  1.4149         0.570087   \n',
#  '     10. B(C  10,C   9)                  1.3989         0.604619   \n',
#  '     11. B(C  11,C  10)                  1.3946         0.614260   \n',
#  '     12. B(C  11,C   8)                  1.3946         0.614221   \n',
#  '     13. B(F  12,C   0)                  1.3565         0.588109   \n',
#  '     14. B(F  13,C   1)                  1.3576         0.585715   \n',
#  '     15. B(F  14,C   2)                  1.3564         0.588363   \n',
#  '     16. B(F  15,C   4)                  1.3565         0.588057   \n',
#  '     17. B(F  16,C   5)                  1.3576         0.585667   \n',
#  '     18. B(F  17,C   9)                  1.3575         0.585871   \n',
#  '     19. B(F  18,C  10)                  1.3565         0.588025   \n',
#  '     20. B(F  19,C  11)                  1.3564         0.588328   \n',
#  '     21. B(F  20,C   8)                  1.3565         0.588074   \n',
#  '     22. B(F  21,C   7)                  1.3575         0.585815   \n',
#  '     23. B(B  22,C   6)                  1.6071         0.325946   \n',
#  '     24. B(B  22,C   3)                  1.6065         0.326662   \n',
#  '     25. B(C  23,B  22)                  1.6067         0.326499   \n',
#  '     26. B(C  24,C  23)                  1.4149         0.570268   \n',
#  '     27. B(C  25,C  24)                  1.3988         0.604947   \n',
#  '     28. B(C  26,C  23)                  1.4147         0.570552   \n',
#  '     29. B(C  27,C  25)                  1.3947         0.614125   \n',
#  '     30. B(C  28,C  27)                  1.3948         0.613954   \n',
#  '     31. B(C  28,C  26)                  1.3990         0.604561   \n',
#  '     32. B(F  29,C  24)                  1.3576         0.585660   \n',
#  '     33. B(F  30,C  25)                  1.3565         0.588059   \n',
#  '     34. B(F  31,C  26)                  1.3576         0.585781   \n',
#  '     35. B(F  32,C  28)                  1.3565         0.588068   \n',
#  '     36. B(F  33,C  27)                  1.3564         0.588361   \n',
#  '     37. A(C   1,C   0,C   2)          120.3107         0.431338   \n',
#  '     38. A(C   2,C   0,F  12)          119.7945         0.424518   \n',
#  '     39. A(C   1,C   0,F  12)          119.8942         0.423363   \n',
#  '     40. A(C   3,C   1,F  13)          121.3013         0.418717   \n',
#  '     41. A(C   0,C   1,C   3)          120.5576         0.425729   \n',
#  '     42. A(C   0,C   1,F  13)          118.1190         0.423055   \n',
#  '     43. A(C   0,C   2,C   4)          119.9543         0.432550   \n',
#  '     44. A(C   4,C   2,F  14)          120.0188         0.424580   \n',
#  '     45. A(C   0,C   2,F  14)          120.0269         0.424551   \n',
#  '     46. A(C   5,C   3,B  22)          120.8078         0.385068   \n',
#  '     47. A(C   1,C   3,C   5)          118.3034         0.421318   \n',
#  '     48. A(C   1,C   3,B  22)          120.8888         0.385103   \n',
#  '     49. A(C   2,C   4,F  15)          119.8031         0.424541   \n',
#  '     50. A(C   2,C   4,C   5)          120.3067         0.431405   \n',
#  '     51. A(C   5,C   4,F  15)          119.8897         0.423393   \n',
#  '     52. A(C   3,C   5,C   4)          120.5668         0.425726   \n',
#  '     53. A(C   4,C   5,F  16)          118.1011         0.423085   \n',
#  '     54. A(C   3,C   5,F  16)          121.3101         0.418672   \n',
#  '     55. A(C   9,C   6,B  22)          120.8781         0.384887   \n',
#  '     56. A(C   7,C   6,B  22)          120.8548         0.384886   \n',
#  '     57. A(C   7,C   6,C   9)          118.2671         0.421200   \n',
#  '     58. A(C   6,C   7,C   8)          120.5802         0.425664   \n',
#  '     59. A(C   6,C   7,F  21)          121.3300         0.418651   \n',
#  '     60. A(C   8,C   7,F  21)          118.0678         0.423083   \n',
#  '     61. A(C  11,C   8,F  20)          119.7937         0.424556   \n',
#  '     62. A(C   7,C   8,F  20)          119.8936         0.423374   \n',
#  '     63. A(C   7,C   8,C  11)          120.3121         0.431396   \n',
#  '     64. A(C  10,C   9,F  17)          118.0757         0.423077   \n',
#  '     65. A(C   6,C   9,F  17)          121.3278         0.418660   \n',
#  '     66. A(C   6,C   9,C  10)          120.5745         0.425653   \n',
#  '     67. A(C  11,C  10,F  18)          119.7904         0.424554   \n',
#  '     68. A(C   9,C  10,C  11)          120.3163         0.431388   \n',
#  '     69. A(C   9,C  10,F  18)          119.8927         0.423355   \n',
#  '     70. A(C  10,C  11,F  19)          120.0276         0.424593   \n',
#  '     71. A(C   8,C  11,F  19)          120.0229         0.424588   \n',
#  '     72. A(C   8,C  11,C  10)          119.9495         0.432611   \n',
#  '     73. A(C   6,B  22,C  23)          120.1034         0.352643   \n',
#  '     74. A(C   3,B  22,C  23)          119.8535         0.352774   \n',
#  '     75. A(C   3,B  22,C   6)          120.0431         0.352673   \n',
#  '     76. A(C  24,C  23,C  26)          118.2939         0.421287   \n',
#  '     77. A(B  22,C  23,C  26)          120.9046         0.385055   \n',
#  '     78. A(B  22,C  23,C  24)          120.8014         0.385022   \n',
#  '     79. A(C  25,C  24,F  29)          118.0880         0.423091   \n',
#  '     80. A(C  23,C  24,F  29)          121.3162         0.418657   \n',
#  '     81. A(C  23,C  24,C  25)          120.5740         0.425719   \n',
#  '     82. A(C  27,C  25,F  30)          119.8019         0.424542   \n',
#  '     83. A(C  24,C  25,F  30)          119.8915         0.423400   \n',
#  '     84. A(C  24,C  25,C  27)          120.3060         0.431413   \n',
#  '     85. A(C  28,C  26,F  31)          118.1140         0.423058   \n',
#  '     86. A(C  23,C  26,F  31)          121.3052         0.418709   \n',
#  '     87. A(C  23,C  26,C  28)          120.5586         0.425708   \n',
#  '     88. A(C  28,C  27,F  33)          120.0302         0.424560   \n',
#  '     89. A(C  25,C  27,F  33)          120.0175         0.424581   \n',
#  '     90. A(C  25,C  27,C  28)          119.9523         0.432560   \n',
#  '     91. A(C  27,C  28,F  32)          119.7907         0.424522   \n',
#  '     92. A(C  26,C  28,F  32)          119.8940         0.423353   \n',
#  '     93. A(C  26,C  28,C  27)          120.3147         0.431342   \n',
#  '     94. D(F  13,C   1,C   0,C   2)    178.4991         0.025221   \n',
#  '     95. D(C   3,C   1,C   0,F  12)   -179.5422         0.025221   \n',
#  '     96. D(F  13,C   1,C   0,F  12)     -1.2318         0.025221   \n',
#  '     97. D(C   3,C   1,C   0,C   2)      0.1887         0.025221   \n',
#  '     98. D(C   4,C   2,C   0,C   1)     -0.0989         0.026046   \n',
#  '     99. D(C   4,C   2,C   0,F  12)    179.6322         0.026046   \n',
#  '    100. D(F  14,C   2,C   0,C   1)    179.9050         0.026046   \n',
#  '    101. D(F  14,C   2,C   0,F  12)     -0.3639         0.026046   \n',
#  '    102. D(B  22,C   3,C   1,F  13)      1.6427         0.022342   \n',
#  '    103. D(C   5,C   3,C   1,C   0)     -0.0851         0.022342   \n',
#  '    104. D(C   5,C   3,C   1,F  13)   -178.3410         0.022342   \n',
#  '    105. D(B  22,C   3,C   1,C   0)    179.8986         0.022342   \n',
#  '    106. D(F  15,C   4,C   2,C   0)    179.6429         0.026067   \n',
#  '    107. D(C   5,C   4,C   2,C   0)     -0.0933         0.026067   \n',
#  '    108. D(C   5,C   4,C   2,F  14)    179.9028         0.026067   \n',
#  '    109. D(F  15,C   4,C   2,F  14)     -0.3611         0.026067   \n',
#  '    110. D(F  16,C   5,C   4,F  15)     -1.2208         0.025246   \n',
#  '    111. D(C   3,C   5,C   4,F  15)   -179.5391         0.025246   \n',
#  '    112. D(F  16,C   5,C   3,B  22)      1.6461         0.022318   \n',
#  '    113. D(F  16,C   5,C   3,C   1)   -178.3701         0.022318   \n',
#  '    114. D(C   4,C   5,C   3,B  22)    179.9098         0.022318   \n',
#  '    115. D(F  16,C   5,C   4,C   2)    178.5151         0.025246   \n',
#  '    116. D(C   4,C   5,C   3,C   1)     -0.1065         0.022318   \n',
#  '    117. D(C   3,C   5,C   4,C   2)      0.1969         0.025246   \n',
#  '    118. D(F  21,C   7,C   6,B  22)      1.6603         0.022293   \n',
#  '    119. D(F  21,C   7,C   6,C   9)   -178.3430         0.022293   \n',
#  '    120. D(C   8,C   7,C   6,B  22)    179.9220         0.022293   \n',
#  '    121. D(C   8,C   7,C   6,C   9)     -0.0814         0.022293   \n',
#  '    122. D(F  20,C   8,C   7,C   6)   -179.5703         0.025231   \n',
#  '    123. D(C  11,C   8,C   7,F  21)    178.4761         0.025231   \n',
#  '    124. D(C  11,C   8,C   7,C   6)      0.1589         0.025231   \n',
#  '    125. D(F  20,C   8,C   7,F  21)     -1.2531         0.025231   \n',
#  '    126. D(F  17,C   9,C   6,B  22)      1.6623         0.022294   \n',
#  '    127. D(F  17,C   9,C   6,C   7)   -178.3343         0.022294   \n',
#  '    128. D(C  10,C   9,C   6,B  22)    179.9209         0.022294   \n',
#  '    129. D(C  10,C   9,C   6,C   7)     -0.0757         0.022294   \n',
#  '    130. D(F  18,C  10,C   9,F  17)     -1.2571         0.025222   \n',
#  '    131. D(F  18,C  10,C   9,C   6)   -179.5712         0.025222   \n',
#  '    132. D(C  11,C  10,C   9,F  17)    178.4713         0.025222   \n',
#  '    133. D(C  11,C  10,C   9,C   6)      0.1572         0.025222   \n',
#  '    134. D(F  19,C  11,C  10,F  18)     -0.3503         0.026080   \n',
#  '    135. D(C   8,C  11,C  10,F  18)    179.6487         0.026080   \n',
#  '    136. D(C   8,C  11,C  10,C   9)     -0.0800         0.026080   \n',
#  '    137. D(F  19,C  11,C   8,F  20)     -0.3492         0.026077   \n',
#  '    138. D(F  19,C  11,C   8,C   7)    179.9214         0.026077   \n',
#  '    139. D(F  19,C  11,C  10,C   9)    179.9211         0.026080   \n',
#  '    140. D(C  10,C  11,C   8,F  20)    179.6519         0.026077   \n',
#  '    141. D(C  10,C  11,C   8,C   7)     -0.0776         0.026077   \n',
#  '    142. D(C  23,B  22,C   6,C   9)     31.7494         0.006468   \n',
#  '    143. D(C   3,B  22,C   6,C   9)   -148.2527         0.006468   \n',
#  '    144. D(C   3,B  22,C   6,C   7)     31.7438         0.006468   \n',
#  '    145. D(C  23,B  22,C   3,C   5)     32.3831         0.006492   \n',
#  '    146. D(C  23,B  22,C   3,C   1)   -147.6002         0.006492   \n',
#  '    147. D(C  23,B  22,C   6,C   7)   -148.2540         0.006468   \n',
#  '    148. D(C   6,B  22,C   3,C   5)   -147.6147         0.006492   \n',
#  '    149. D(C   6,B  22,C   3,C   1)     32.4019         0.006492   \n',
#  '    150. D(C  26,C  23,B  22,C   6)     32.2494         0.006486   \n',
#  '    151. D(C  26,C  23,B  22,C   3)   -147.7484         0.006486   \n',
#  '    152. D(C  24,C  23,B  22,C   6)   -147.7731         0.006486   \n',
#  '    153. D(C  24,C  23,B  22,C   3)     32.2291         0.006486   \n',
#  '    154. D(F  29,C  24,C  23,B  22)      1.6516         0.022309   \n',
#  '    155. D(C  25,C  24,C  23,C  26)     -0.1052         0.022309   \n',
#  '    156. D(C  25,C  24,C  23,B  22)    179.9167         0.022309   \n',
#  '    157. D(F  29,C  24,C  23,C  26)   -178.3704         0.022309   \n',
#  '    158. D(F  30,C  25,C  24,F  29)     -1.2259         0.025251   \n',
#  '    159. D(F  30,C  25,C  24,C  23)   -179.5460         0.025251   \n',
#  '    160. D(C  27,C  25,C  24,F  29)    178.5094         0.025251   \n',
#  '    161. D(C  27,C  25,C  24,C  23)      0.1894         0.025251   \n',
#  '    162. D(F  31,C  26,C  23,C  24)   -178.3318         0.022332   \n',
#  '    163. D(F  31,C  26,C  23,B  22)      1.6462         0.022332   \n',
#  '    164. D(C  28,C  26,C  23,C  24)     -0.0783         0.022332   \n',
#  '    165. D(C  28,C  26,C  23,B  22)    179.8998         0.022332   \n',
#  '    166. D(F  33,C  27,C  25,F  30)     -0.3583         0.026068   \n',
#  '    167. D(F  33,C  27,C  25,C  24)    179.9061         0.026068   \n',
#  '    168. D(C  28,C  27,C  25,F  30)    179.6479         0.026068   \n',
#  '    169. D(C  28,C  27,C  25,C  24)     -0.0877         0.026068   \n',
#  '    170. D(F  32,C  28,C  27,F  33)     -0.3604         0.026053   \n',
#  '    171. D(F  32,C  28,C  27,C  25)    179.6334         0.026053   \n',
#  '    172. D(C  26,C  28,C  27,F  33)    179.9098         0.026053   \n',
#  '    173. D(C  26,C  28,C  27,C  25)     -0.0964         0.026053   \n',
#  '    174. D(F  32,C  28,C  26,F  31)     -1.2414         0.025217   \n',
#  '    175. D(F  32,C  28,C  26,C  23)   -179.5496         0.025217   \n',
#  '    176. D(C  27,C  28,C  26,F  31)    178.4881         0.025217   \n',
#  '    177. D(C  27,C  28,C  26,C  23)      0.1799         0.025217   \n',
#  '    -----------------------------------------------------------------\n',
#  '\n',
#  'Number of atoms                         .... 34\n',
#  'Number of degrees of freedom            .... 177\n',
#  '\n',
#  '         *************************************************************\n',
#  '         *                GEOMETRY OPTIMIZATION CYCLE   1            *\n',
#  '         *************************************************************\n',
#  '---------------------------------\n',
#  'CARTESIAN COORDINATES (ANGSTROEM)\n',
#  '---------------------------------\n',
#  '  C     -0.388380    4.424790    0.199570\n',
#  '  C     -1.117160    3.239110    0.057840\n',
#  '  C     -0.813170    5.409890    1.090970\n',
#  '  C     -2.294770    3.024230    0.811720\n',
#  '  C     -1.970730    5.215180    1.844170\n',
#  '  C     -2.710790    4.035890    1.709020\n',
#  '  C     -2.387740    0.286350    0.317340\n',
#  '  C     -1.073940    0.043190    0.783050\n',
#  '  C     -0.425910   -1.161030    0.488420\n',
#  '  C     -3.022490   -0.717320   -0.451950\n',
#  '  C     -2.361890   -1.915820   -0.742170\n',
#  '  C     -1.067520   -2.137750   -0.272760\n',
#  '  F      0.733810    4.620730   -0.536850\n',
#  '  F     -0.680780    2.323880   -0.844910\n',
#  '  F     -0.101110    6.556470    1.225220\n',
#  '  F     -2.377070    6.172140    2.715490\n',
#  '  F     -3.812950    3.879970    2.486210\n',
#  '  F     -4.268980   -0.536050   -0.958150\n',
#  '  F     -2.980230   -2.865090   -1.488270\n',
#  '  F     -0.433090   -3.302590   -0.556290\n',
#  '  F      0.830390   -1.383100    0.949350\n',
#  '  F     -0.419290    0.948910    1.553770\n',
#  '  B     -3.139120    1.666670    0.653490\n',
#  '  C     -4.735620    1.692370    0.832090\n',
#  '  C     -5.487880    2.831830    0.461200\n',
#  '  C     -6.877850    2.848400    0.617140\n',
#  '  C     -5.425280    0.577620    1.364200\n',
#  '  C     -7.540070    1.740340    1.145180\n',
#  '  C     -6.815360    0.608620    1.518510\n',
#  '  F     -4.892990    3.922700   -0.085800\n',
#  '  F     -7.586460    3.944750    0.248400\n',
#  '  F     -4.761110   -0.534270    1.771050\n',
#  '  F     -7.461940   -0.464430    2.038670\n',
#  '  F     -8.887860    1.763460    1.295610\n',
#  '\n',
#  '----------------------------\n',
#  'CARTESIAN COORDINATES (A.U.)\n',
#  '----------------------------\n',
#  '  NO LB      ZA    FRAG     MASS         X           Y           Z\n',
#  '   0 C     6.0000    0    12.011   -0.733932    8.361641    0.377133\n',
#  '   1 C     6.0000    0    12.011   -2.111126    6.121031    0.109302\n',
#  '   2 C     6.0000    0    12.011   -1.536669   10.223211    2.061635\n',
#  '   3 C     6.0000    0    12.011   -4.336487    5.714966    1.533928\n',
#  '   4 C     6.0000    0    12.011   -3.724140    9.855262    3.484976\n',
#  '   5 C     6.0000    0    12.011   -5.122651    7.626727    3.229580\n',
#  '   6 C     6.0000    0    12.011   -4.512175    0.541123    0.599686\n',
#  '   7 C     6.0000    0    12.011   -2.029452    0.081617    1.479750\n',
#  '   8 C     6.0000    0    12.011   -0.804853   -2.194029    0.922980\n',
#  '   9 C     6.0000    0    12.011   -5.711678   -1.355538   -0.854062\n',
#  '  10 C     6.0000    0    12.011   -4.463325   -3.620375   -1.402498\n',
#  '  11 C     6.0000    0    12.011   -2.017320   -4.039762   -0.515442\n',
#  '  12 F     9.0000    0    18.998    1.386700    8.731914   -1.014499\n',
#  '  13 F     9.0000    0    18.998   -1.286488    4.391497   -1.596649\n',
#  '  14 F     9.0000    0    18.998   -0.191070   12.389933    2.315330\n',
#  '  15 F     9.0000    0    18.998   -4.492011   11.663654    5.131532\n',
#  '  16 F     9.0000    0    18.998   -7.205431    7.332081    4.698256\n',
#  '  17 F     9.0000    0    18.998   -8.067203   -1.012988   -1.810641\n',
#  '  18 F     9.0000    0    18.998   -5.631819   -5.414235   -2.812423\n',
#  '  19 F     9.0000    0    18.998   -0.818421   -6.240991   -1.051236\n',
#  '  20 F     9.0000    0    18.998    1.569210   -2.613680    1.794012\n',
#  '  21 F     9.0000    0    18.998   -0.792343    1.793180    2.936200\n',
#  '  22 B     5.0000    0    10.810   -5.932077    3.149550    1.234917\n',
#  '  23 C     6.0000    0    12.011   -8.949025    3.198116    1.572422\n',
#  '  24 C     6.0000    0    12.011  -10.370590    5.351383    0.871542\n',
#  '  25 C     6.0000    0    12.011  -12.997253    5.382696    1.166226\n',
#  '  26 C     6.0000    0    12.011  -10.252293    1.091544    2.577964\n',
#  '  27 C     6.0000    0    12.011  -14.248667    3.288766    2.164077\n',
#  '  28 C     6.0000    0    12.011  -12.879164    1.150125    2.869568\n',
#  '  29 F     9.0000    0    18.998   -9.246411    7.412829   -0.162139\n',
#  '  30 F     9.0000    0    18.998  -14.336332    7.454497    0.469408\n',
#  '  31 F     9.0000    0    18.998   -8.997194   -1.009624    3.346799\n',
#  '  32 F     9.0000    0    18.998  -14.101023   -0.877646    3.852528\n',
#  '  33 F     9.0000    0    18.998  -16.795621    3.332456    2.448348\n',
#  '\n',
#  '--------------------------------\n',
#  'INTERNAL COORDINATES (ANGSTROEM)\n',
#  '--------------------------------\n',
#  ' C      0   0   0     0.000000000000     0.00000000     0.00000000\n',
#  ' C      1   0   0     1.398944153174     0.00000000     0.00000000\n',
#  ' C      1   2   0     1.394798377580   120.31074804     0.00000000\n',
#  ' C      2   1   3     1.414663840246   120.55759453     0.18869748\n',
#  ' C      3   1   2     1.394692574620   119.95430500   359.90107344\n',
#  ' C      5   3   1     1.398813508013   120.30673576   359.90670680\n',
#  ' C      4   2   1     2.783710096203    94.73532731   195.48673225\n',
#  ' C      7   4   2     1.414949832927    94.56312133    54.42175861\n',
#  ' C      8   7   4     1.398890819971   120.58020838   195.21033870\n',
#  ' C      7   4   2     1.414944569762   144.01757067   257.70956728\n',
#  ' C     10   7   4     1.398936116626   120.57446981   153.34369687\n',
#  ' C     11  10   7     1.394629832572   120.31630592     0.15718655\n',
#  ' F      1   2   3     1.356472372037   119.89422280   180.26913360\n',
#  ' F      2   1   3     1.357582785616   118.11895270   178.49907600\n',
#  ' F      3   1   2     1.356354748029   120.02692217   179.90499501\n',
#  ' F      5   3   1     1.356496656686   119.80308924   179.64286319\n',
#  ' F      6   5   3     1.357605247522   118.10114291   178.51513619\n',
#  ' F     10   7   4     1.357510432004   121.32777522   335.08511341\n',
#  ' F     11  10   7     1.356511370575   119.89272926   180.42880906\n',
#  ' F     12  11  10     1.356371229199   120.02764764   179.92109430\n',
#  ' F      9   8   7     1.356488569727   119.89363843   180.42968559\n',
#  ' F      8   7   4     1.357536246035   121.33003578    16.94866285\n',
#  ' B      4   2   1     1.606528184938   120.88875466   179.89861674\n',
#  ' C     23   4   2     1.606664464037   119.85348745   212.39975169\n',
#  ' C     24  23   4     1.414858152360   120.80144465    32.22906120\n',
#  ' C     25  24  23     1.398788207485   120.57396708   179.91672995\n',
#  ' C     24  23   4     1.414722421608   120.90460605   212.25158260\n',
#  ' C     26  25  24     1.394689403989   120.30604016     0.18935223\n',
#  ' C     28  26  25     1.394765224473   119.95230286   359.91229779\n',
#  ' F     25  24  23     1.357608363631   121.31617198     1.65155834\n',
#  ' F     26  25  24     1.356495721409   119.89150732   180.45401028\n',
#  ' F     27  24  23     1.357552239695   121.30521758     1.64620133\n',
#  ' F     29  28  26     1.356491217996   119.79065903   179.63338244\n',
#  ' F     28  26  25     1.356356001719   120.01750697   179.90610452\n',
#  '\n',
#  '---------------------------\n',
#  'INTERNAL COORDINATES (A.U.)\n',
#  '---------------------------\n',
#  ' C      0   0   0     0.000000000000     0.00000000     0.00000000\n',
#  ' C      1   0   0     2.643621326149     0.00000000     0.00000000\n',
#  ' C      1   2   0     2.635786945664   120.31074804     0.00000000\n',
#  ' C      2   1   3     2.673327229627   120.55759453     0.18869748\n',
#  ' C      3   1   2     2.635587007045   119.95430500   359.90107344\n',
#  ' C      5   3   1     2.643374442574   120.30673576   359.90670680\n',
#  ' C      4   2   1     5.260449718054    94.73532731   195.48673225\n',
#  ' C      7   4   2     2.673867677470    94.56312133    54.42175861\n',
#  ' C      8   7   4     2.643520541002   120.58020838   195.21033870\n',
#  ' C      7   4   2     2.673857731530   144.01757067   257.70956728\n',
#  ' C     10   7   4     2.643606139274   120.57446981   153.34369687\n',
#  ' C     11  10   7     2.635468441758   120.31630592     0.15718655\n',
#  ' F      1   2   3     2.563361291381   119.89422280   180.26913360\n',
#  ' F      2   1   3     2.565459668940   118.11895270   178.49907600\n',
#  ' F      3   1   2     2.563139014218   120.02692217   179.90499501\n',
#  ' F      5   3   1     2.563407182716   119.80308924   179.64286319\n',
#  ' F      6   5   3     2.565502115791   118.10114291   178.51513619\n',
#  ' F     10   7   4     2.565322940429   121.32777522   335.08511341\n',
#  ' F     11  10   7     2.563434987937   119.89272926   180.42880906\n',
#  ' F     12  11  10     2.563170159117   120.02764764   179.92109430\n',
#  ' F      9   8   7     2.563391900579   119.89363843   180.42968559\n',
#  ' F      8   7   4     2.565371721879   121.33003578    16.94866285\n',
#  ' B      4   2   1     3.035898295958   120.88875466   179.89861674\n',
#  ' C     23   4   2     3.036155826134   119.85348745   212.39975169\n',
#  ' C     24  23   4     2.673694426307   120.80144465    32.22906120\n',
#  ' C     25  24  23     2.643326631506   120.57396708   179.91672995\n',
#  ' C     24  23   4     2.673437932357   120.90460605   212.25158260\n',
#  ' C     26  25  24     2.635581015422   120.30604016     0.18935223\n',
#  ' C     28  26  25     2.635724295372   119.95230286   359.91229779\n',
#  ' F     25  24  23     2.565508004383   121.31617198     1.65155834\n',
#  ' F     26  25  24     2.563405415298   119.89150732   180.45401028\n',
#  ' F     27  24  23     2.565401945514   121.30521758     1.64620133\n',
#  ' F     29  28  26     2.563396905082   119.79065903   179.63338244\n',
#  ' F     28  26  25     2.563141383350   120.01750697   179.90610452\n',
#  '\n',
#  '---------------------\n',
#  'BASIS SET INFORMATION\n',
#  '---------------------\n',
#  'There are 3 groups of distinct atoms\n',
#  '\n',
#  ' Group   1 Type C   : 11s6p2d1f contracted to 5s3p2d1f pattern {62111/411/11/1}\n',
#  ' Group   2 Type F   : 11s6p2d1f contracted to 5s3p2d1f pattern {62111/411/11/1}\n',
#  ' Group   3 Type B   : 11s6p2d1f contracted to 5s3p2d1f pattern {62111/411/11/1}\n',
#  '\n',
#  'Atom   0C    basis set group =>   1\n',
#  'Atom   1C    basis set group =>   1\n',
#  'Atom   2C    basis set group =>   1\n',
#  'Atom   3C    basis set group =>   1\n',
#  'Atom   4C    basis set group =>   1\n',
#  'Atom   5C    basis set group =>   1\n',
#  'Atom   6C    basis set group =>   1\n',
#  'Atom   7C    basis set group =>   1\n',
#  'Atom   8C    basis set group =>   1\n',
#  'Atom   9C    basis set group =>   1\n',
#  'Atom  10C    basis set group =>   1\n',
#  'Atom  11C    basis set group =>   1\n',
#  'Atom  12F    basis set group =>   2\n',
#  'Atom  13F    basis set group =>   2\n',
#  'Atom  14F    basis set group =>   2\n',
#  'Atom  15F    basis set group =>   2\n',
#  'Atom  16F    basis set group =>   2\n',
#  'Atom  17F    basis set group =>   2\n',
#  'Atom  18F    basis set group =>   2\n',
#  'Atom  19F    basis set group =>   2\n',
#  'Atom  20F    basis set group =>   2\n',
#  'Atom  21F    basis set group =>   2\n',
#  'Atom  22B    basis set group =>   3\n',
#  'Atom  23C    basis set group =>   1\n',
#  'Atom  24C    basis set group =>   1\n',
#  'Atom  25C    basis set group =>   1\n',
#  'Atom  26C    basis set group =>   1\n',
#  'Atom  27C    basis set group =>   1\n',
#  'Atom  28C    basis set group =>   1\n',
#  'Atom  29F    basis set group =>   2\n',
#  'Atom  30F    basis set group =>   2\n',
#  'Atom  31F    basis set group =>   2\n',
#  'Atom  32F    basis set group =>   2\n',
#  'Atom  33F    basis set group =>   2\n',
#  '---------------------------------\n',
#  'AUXILIARY/J BASIS SET INFORMATION\n',
#  '---------------------------------\n',
#  'There are 3 groups of distinct atoms\n',
#  '\n',
#  ' Group   1 Type C   : 12s5p4d2f1g contracted to 6s4p3d1f1g pattern {711111/2111/211/2/1}\n',
#  ' Group   2 Type F   : 12s5p4d2f1g contracted to 6s4p3d1f1g pattern {711111/2111/211/2/1}\n',
#  ' Group   3 Type B   : 12s5p4d2f1g contracted to 6s4p3d1f1g pattern {711111/2111/211/2/1}\n',
#  '\n',
#  'Atom   0C    basis set group =>   1\n',
#  'Atom   1C    basis set group =>   1\n',
#  'Atom   2C    basis set group =>   1\n',
#  'Atom   3C    basis set group =>   1\n',
#  'Atom   4C    basis set group =>   1\n',
#  'Atom   5C    basis set group =>   1\n',
#  'Atom   6C    basis set group =>   1\n',
#  'Atom   7C    basis set group =>   1\n',
#  'Atom   8C    basis set group =>   1\n',
#  'Atom   9C    basis set group =>   1\n',
#  'Atom  10C    basis set group =>   1\n',
#  'Atom  11C    basis set group =>   1\n',
#  'Atom  12F    basis set group =>   2\n',
#  'Atom  13F    basis set group =>   2\n',
#  'Atom  14F    basis set group =>   2\n',
#  'Atom  15F    basis set group =>   2\n',
#  'Atom  16F    basis set group =>   2\n',
#  'Atom  17F    basis set group =>   2\n',
#  'Atom  18F    basis set group =>   2\n',
#  'Atom  19F    basis set group =>   2\n',
#  'Atom  20F    basis set group =>   2\n',
#  'Atom  21F    basis set group =>   2\n',
#  'Atom  22B    basis set group =>   3\n',
#  'Atom  23C    basis set group =>   1\n',
#  'Atom  24C    basis set group =>   1\n',
#  'Atom  25C    basis set group =>   1\n',
#  'Atom  26C    basis set group =>   1\n',
#  'Atom  27C    basis set group =>   1\n',
#  'Atom  28C    basis set group =>   1\n',
#  'Atom  29F    basis set group =>   2\n',
#  'Atom  30F    basis set group =>   2\n',
#  'Atom  31F    basis set group =>   2\n',
#  'Atom  32F    basis set group =>   2\n',
#  'Atom  33F    basis set group =>   2\n',
#  '--------------------------------------------------------------------------\n',
#  '[[22624,1],2]: A high-performance Open MPI point-to-point messaging module\n',
#  'was unable to find any relevant network interfaces:\n',
#  '\n',
#  'Module: OpenFabrics (openib)\n',
#  '  Host: compute-1-12\n',
#  '\n',
#  'Another transport will be used instead, although this may result in\n',
#  'lower performance.\n',
#  '\n',
#  'NOTE: You can disable this warning by setting the MCA parameter\n',
#  'btl_base_warn_component_unused to 0.\n',
#  '--------------------------------------------------------------------------\n',
#  '\n',
#  '\n',
#  '           ************************************************************\n',
#  '           *        Program running with 4 parallel MPI-processes     *\n',
#  '           *              working on a common directory               *\n',
#  '           ************************************************************\n',
#  '------------------------------------------------------------------------------\n',
#  '                           ORCA GTO INTEGRAL CALCULATION\n',
#  '------------------------------------------------------------------------------\n',
#  '\n',
#  '                         BASIS SET STATISTICS AND STARTUP INFO\n',
#  '\n',
#  ' # of primitive gaussian shells          ...  680\n',
#  ' # of primitive gaussian functions       ... 1564\n',
#  ' # of contracted shells                  ...  374\n',
#  ' # of contracted basis functions         ... 1054\n',
#  ' Highest angular momentum                ...    3\n',
#  ' Maximum contraction depth               ...    6\n',
#  ' Integral package used                   ... LIBINT\n',
#  ' Integral threshhold            Thresh   ...  2.500e-11\n',
#  ' Primitive cut-off              TCut     ...  2.500e-12\n',
#  '\n',
#  '\n',
#  '------------------------------ INTEGRAL EVALUATION ----------------------------\n',
#  '\n',
#  '\n',
#  ' * One electron integrals \n',
#  ' Pre-screening matrix                    ... done\n',
#  ' Shell pair data                         ... done (   0.025 sec)\n',
#  '\n',
#  '[compute-1-12.local:62299] 3 more processes have sent help message help-mpi-btl-base.txt / btl:no-nics\n',
#  '[compute-1-12.local:62299] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages\n',
#  '--------------------------------------------------------------------------\n',
#  '[[22612,1],3]: A high-performance Open MPI point-to-point messaging module\n',
#  'was unable to find any relevant network interfaces:\n',
#  '\n',
#  'Module: OpenFabrics (openib)\n',
#  '  Host: compute-1-12\n',
#  '\n',
#  'Another transport will be used instead, although this may result in\n',
#  'lower performance.\n',
#  '\n',
#  'NOTE: You can disable this warning by setting the MCA parameter\n',
#  'btl_base_warn_component_unused to 0.\n',
#  '--------------------------------------------------------------------------\n',
#  '\n',
#  '\n',
#  '           ************************************************************\n',
#  '           *        Program running with 4 parallel MPI-processes     *\n',
#  '           *              working on a common directory               *\n',
#  '           ************************************************************\n',
#  '-------------------------------------------------------------------------------\n',
#  '                                 ORCA SCF\n',
#  '-------------------------------------------------------------------------------\n',
#  '\n',
#  '------------\n',
#  'SCF SETTINGS\n',
#  '------------\n',
#  'Hamiltonian:\n',
#  ' Density Functional     Method          .... DFT(GTOs)\n',
#  ' Exchange Functional    Exchange        .... WB97X-D3\n',
#  ' Correlation Functional Correlation     .... WB97X-D3\n',
#  ' Gradients option       PostSCFGGA      .... off\n',
#  ' Hybrid DFT is turned on\n',
#  '   Fraction HF Exchange ScalHFX         ....  0.195728\n',
#  '   Scaling of DF-GGA-X  ScalDFX         ....  0.000000\n',
#  '   Scaling of DF-GGA-C  ScalDFC         ....  1.000000\n',
#  '   Scaling of DF-LDA-C  ScalLDAC        ....  1.000000\n',
#  '   Perturbative correction              ....  0.000000\n',
#  '   Density functional embedding theory  .... OFF\n',
#  ' Long-range corrected/Screened/Range-Separated Hybrid DFT is turned on\n',
#  '   Amount of maximum screened exact exchange              ....  0.804272\n',
#  '   Range separation parameter mu (erf(mu*r12)/r12)        ....  0.250000\n',
#  '\n',
#  '\n',
#  'General Settings:\n',
#  ' Integral files         IntName         .... BCF\n',
#  ' Hartree-Fock type      HFTyp           .... RHF\n',
#  ' Total Charge           Charge          ....    0\n',
#  ' Multiplicity           Mult            ....    1\n',
#  ' Number of Electrons    NEL             ....  248\n',
#  ' Basis Dimension        Dim             .... 1054\n',
#  ' Nuclear Repulsion      ENuc            ....   3807.3832895272 Eh\n',
#  '\n',
#  'Convergence Acceleration:\n',
#  ' DIIS                   CNVDIIS         .... on\n',
#  '   Start iteration      DIISMaxIt       ....    12\n',
#  '   Startup error        DIISStart       ....  0.200000\n',
#  '   # of expansion vecs  DIISMaxEq       ....     5\n',
#  '   Bias factor          DIISBfac        ....   1.050\n',
#  '   Max. coefficient     DIISMaxC        ....  10.000\n',
#  ' Newton-Raphson         CNVNR           .... off\n',
#  ' SOSCF                  CNVSOSCF        .... on\n',
#  '   Start iteration      SOSCFMaxIt      ....   150\n',
#  '   Startup grad/error   SOSCFStart      ....  0.003300\n',
#  ' Level Shifting         CNVShift        .... on\n',
#  '   Level shift para.    LevelShift      ....    0.2500\n',
#  '   Turn off err/grad.   ShiftErr        ....    0.0010\n',
#  ' Zerner damping         CNVZerner       .... off\n',
#  ' Static damping         CNVDamp         .... on\n',
#  '   Fraction old density DampFac         ....    0.7000\n',
#  '   Max. Damping (<1)    DampMax         ....    0.9800\n',
#  '   Min. Damping (>=0)   DampMin         ....    0.0000\n',
#  '   Turn off err/grad.   DampErr         ....    0.1000\n',
#  ' Fernandez-Rico         CNVRico         .... off\n',
#  '\n',
#  'SCF Procedure:\n',
#  ' Maximum # iterations   MaxIter         ....   125\n',
#  ' SCF integral mode      SCFMode         .... Direct\n',
#  '   Integral package                     .... LIBINT\n',
#  ' Reset frequency        DirectResetFreq ....    20\n',
#  ' Integral Threshold     Thresh          ....  2.500e-11 Eh\n',
#  ' Primitive CutOff       TCut            ....  2.500e-12 Eh\n',
#  '\n',
#  'Convergence Tolerance:\n',
#  ' Convergence Check Mode ConvCheckMode   .... Total+1el-Energy\n',
#  ' Convergence forced     ConvForced      .... 0\n',
#  ' Energy Change          TolE            ....  1.000e-08 Eh\n',
#  ' 1-El. energy change                    ....  1.000e-05 Eh\n',
#  ' Orbital Gradient       TolG            ....  1.000e-05\n',
#  ' Orbital Rotation angle TolX            ....  1.000e-05\n',
#  ' DIIS Error             TolErr          ....  5.000e-07\n',
#  '\n',
#  '\n',
#  'Diagonalization of the overlap matrix:\n',
#  'Smallest eigenvalue                        ... 1.407e-05\n',
#  'Time for diagonalization                   ...    0.381 sec\n',
#  'Threshold for overlap eigenvalues          ... 1.000e-08\n',
#  'Number of eigenvalues below threshold      ... 0\n',
#  'Time for construction of square roots      ...    0.272 sec\n',
#  'Total time needed                          ...    0.657 sec\n',
#  '\n',
#  '-------------------\n',
#  'DFT GRID GENERATION\n',
#  '-------------------\n',
#  '\n',
#  'General Integration Accuracy     IntAcc      ...  4.340\n',
#  'Radial Grid Type                 RadialGrid  ... Gauss-Chebyshev\n',
#  'Angular Grid (max. acc.)         AngularGrid ... Lebedev-110\n',
#  'Angular grid pruning method      GridPruning ... 3 (G Style)\n',
#  'Weight generation scheme         WeightScheme... Becke\n',
#  'Basis function cutoff            BFCut       ...    1.0000e-11\n',
#  'Integration weight cutoff        WCut        ...    1.0000e-14\n',
#  'Grids for H and He will be reduced by one unit\n',
#  '\n',
#  '# of grid points (after initial pruning)     ...  57586 (   0.0 sec)\n',
#  '# of grid points (after weights+screening)   ...  51977 (   0.2 sec)\n',
#  'nearest neighbour list constructed           ...    0.0 sec\n',
#  'Grid point re-assignment to atoms done       ...    0.0 sec\n',
#  'Grid point division into batches done        ...    0.1 sec\n',
#  'Reduced shell lists constructed in    0.6 sec\n',
#  '\n',
#  'Total number of grid points                  ...    51977\n',
#  'Total number of batches                      ...      830\n',
#  'Average number of points per batch           ...       62\n',
#  'Average number of grid points per atom       ...     1529\n',
#  'Average number of shells per batch           ...   162.97 (43.57%)\n',
#  'Average number of basis functions per batch  ...   456.37 (43.30%)\n',
#  'Average number of large shells per batch     ...   111.50 (68.42%)\n',
#  'Average number of large basis fcns per batch ...   311.22 (68.19%)\n',
#  'Maximum spatial batch extension              ...  10.85, 14.11, 14.40 au\n',
#  'Average spatial batch extension              ...   0.52,  0.52,  0.56 au\n',
#  '\n',
#  'Time for grid setup =    0.825 sec\n',
#  '\n',
#  '------------------------------\n',
#  'INITIAL GUESS: MODEL POTENTIAL\n',
#  '------------------------------\n',
#  'Loading Hartree-Fock densities                     ... done\n',
#  'Calculating cut-offs                               ... done\n',
#  'Setting up the integral package                    ... done\n',
#  'Initializing the effective Hamiltonian             ... done\n',
#  'Starting the Coulomb interaction                   ... done (   1.6 sec)\n',
#  'Reading the grid                                   ... done\n',
#  'Mapping shells                                     ... done\n',
#  'Starting the XC term evaluation                    ... done (   1.4 sec)\n',
#  '  promolecular density results\n',
#  '     # of electrons  =    247.997876615\n',
#  '     EX              =   -245.799561126\n',
#  '     EC              =     -8.614124409\n',
#  '     EX+EC           =   -254.413685536\n',
#  'Transforming the Hamiltonian                       ... done (   0.2 sec)\n',
#  'Diagonalizing the Hamiltonian                      ... [compute-1-12.local:62319] 3 more processes have sent help message help-mpi-btl-base.txt / btl:no-nics\n',
#  '[compute-1-12.local:62319] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages\n',
#  'done (   0.4 sec)\n',
#  'Back transforming the eigenvectors                 ... done (   0.1 sec)\n',
#  'Now organizing SCF variables                       ... done\n',
#  '                      ------------------\n',
#  '                      INITIAL GUESS DONE (   4.7 sec)\n',
#  '                      ------------------\n',
#  '\n',
#  '--------------------\n',
#  'CPCM SOLVATION MODEL\n',
#  '--------------------\n',
#  'CPCM parameters:\n',
#  '  Epsilon                                         ...       3.0000\n',
#  '  Refrac                                          ...       1.3300\n',
#  '  Rsolv                                           ...       1.3000\n',
#  '  Surface type                                    ...    GEPOL SES\n',
#  '  Epsilon function type                           ...         CPCM\n',
#  'Radii:\n',
#  ' Radius for C  used is    3.7795 Bohr (=   2.0000 Ang.)\n',
#  ' Radius for F  used is    3.2503 Bohr (=   1.7200 Ang.)\n',
#  ' Radius for B  used is    3.8692 Bohr (=   2.0475 Ang.)\n',
#  'Calculating surface                               ...        done! (  0.2s)\n',
#  'GEPOL surface points                              ...         1271\n',
#  'GEPOL Volume                                      ...    2893.2222\n',
#  'GEPOL Surface-area                                ...    1368.8219\n',
#  'Calculating surface distance matrix               ...        done! (  0.0s)\n',
#  'Performing Cholesky decomposition & store         ...        done! (  0.1s)\n',
#  'Overall time for CPCM initialization              ...                 0.3s\n',
#  '--------------\n',
#  'SCF ITERATIONS\n',
#  '--------------\n',
#  'ITER       Energy         Delta-E        Max-DP      RMS-DP      [F,P]     Damp\n',
#  '               ***  Starting incremental Fock matrix formation  ***\n',
#  '  0  -2208.3345768521   0.000000000000 0.03210540  0.00033851  0.1330766 0.7000\n',
#  '  1  -2208.4424684233  -0.107891571223 0.02505718  0.00025184  0.0762295 0.7000\n',
#  '                               ***Turning on DIIS***\n',
#  '  2  -2208.4980694884  -0.055601065062 0.04515702  0.00052762  0.0365408 0.0000\n',
#  '  3  -2208.5948363127  -0.096766824312 0.03123275  0.00025491  0.0306724 0.0000\n',
#  '  4  -2208.6076052589  -0.012768946179 0.00711464  0.00006693  0.0050101 0.0000\n',
#  '  5  -2208.6082284783  -0.000623219471 0.00466628  0.00003323  0.0021951 0.0000\n',
#  '                      *** Initiating the SOSCF procedure ***\n',
#  '                           *** Shutting down DIIS ***\n',
#  '                      *** Re-Reading the Fockian *** \n',
#  '                      *** Removing any level shift *** \n',
#  'ITER      Energy       Delta-E        Grad      Rot      Max-DP    RMS-DP\n',
#  '  6  -2208.60843031  -0.0002018276  0.002850  0.002850  0.003732  0.000017\n',
#  '               *** Restarting incremental Fock matrix formation ***\n',
#  '  7  -2208.60851090  -0.0000805962  0.001736  0.005186  0.001788  0.000010\n',
#  '  8  -2208.60854474  -0.0000338425  0.000623  0.005299  0.003332  0.000014\n',
#  '  9  -2208.60855360  -0.0000088512  0.000205  0.001225  0.000215  0.000003\n',
#  ' 10  -2208.60855674  -0.0000031458  0.000035  0.000115  0.000103  0.000001\n',
#  ' 11  -2208.60855681  -0.0000000663  0.000018  0.000037  0.000039  0.000000\n',
#  ' 12  -2208.60855687  -0.0000000592  0.000007  0.000018  0.000020  0.000000\n',
#  ' 13  -2208.60855687  -0.0000000025  0.000004  0.000009  0.000007  0.000000\n',
#  '                  ***Gradient check signals convergence***\n',
#  '              ***Rediagonalizing the Fockian in SOSCF/NRSCF***\n',
#  '\n',
#  '               *****************************************************\n',
#  '               *                     SUCCESS                       *\n',
#  '               *           SCF CONVERGED AFTER  14 CYCLES          *\n',
#  '               *****************************************************\n',
#  '\n',
#  'Setting up the final grid:\n',
#  '\n',
#  'General Integration Accuracy     IntAcc      ...  4.670\n',
#  'Radial Grid Type                 RadialGrid  ... Gauss-Chebyshev\n',
#  'Angular Grid (max. acc.)         AngularGrid ... Lebedev-302\n',
#  'Angular grid pruning method      GridPruning ... 3 (G Style)\n',
#  'Weight generation scheme         WeightScheme... Becke\n',
#  'Basis function cutoff            BFCut       ...    1.0000e-11\n',
#  'Integration weight cutoff        WCut        ...    1.0000e-14\n',
#  'Grids for H and He will be reduced by one unit\n',
#  '\n',
#  '# of grid points (after initial pruning)     ... 212024 (   0.0 sec)\n',
#  '# of grid points (after weights+screening)   ... 186645 (   0.8 sec)\n',
#  'nearest neighbour list constructed           ...    0.0 sec\n',
#  'Grid point re-assignment to atoms done       ...    0.1 sec\n',
#  'Grid point division into batches done        ...    1.2 sec\n',
#  'Reduced shell lists constructed in    2.7 sec\n',
#  '\n',
#  'Total number of grid points                  ...   186645\n',
#  'Total number of batches                      ...     2935\n',
#  'Average number of points per batch           ...       63\n',
#  'Average number of grid points per atom       ...     5490\n',
#  'Average number of shells per batch           ...   152.09 (40.67%)\n',
#  'Average number of basis functions per batch  ...   422.57 (40.09%)\n',
#  'Average number of large shells per batch     ...   103.96 (68.35%)\n',
#  'Average number of large basis fcns per batch ...   288.52 (68.28%)\n',
#  'Maximum spatial batch extension              ...   9.84, 13.98, 18.63 au\n',
#  'Average spatial batch extension              ...   0.34,  0.34,  0.37 au\n',
#  '\n',
#  'Final grid set up in    3.6 sec\n',
#  'Final integration                            ... done (   5.3 sec)\n',
#  'Change in XC energy                          ...     0.005322101\n',
#  'Integrated number of electrons               ...   247.999805389\n',
#  'Previous integrated no of electrons          ...   247.998628820\n',
#  '\n',
#  '----------------\n',
#  'TOTAL SCF ENERGY\n',
#  '----------------\n',
#  '\n',
#  'Total Energy       :        -2208.60323476 Eh          -60099.14940 eV\n',
#  '\n',
#  'Components:\n',
#  'Nuclear Repulsion  :         3807.38328953 Eh          103604.16644 eV\n',
#  'Electronic Energy  :        -6015.98652428 Eh         -163703.31584 eV\n',
#  'One Electron Energy:       -10635.29458871 Eh         -289401.07863 eV\n',
#  'Two Electron Energy:         4619.30806443 Eh          125697.76278 eV\n',
#  'CPCM Dielectric    :           -0.00716230 Eh              -0.19490 eV\n',
#  '\n',
#  'Virial components:\n',
#  'Potential Energy   :        -4408.02734034 Eh         -119948.52200 eV\n',
#  'Kinetic Energy     :         2199.42410558 Eh           59849.37260 eV\n',
#  'Virial Ratio       :            2.00417342\n',
#  '\n',
#  '\n',
#  'DFT components:\n',
#  'N(Alpha)           :      123.999902694311 electrons\n',
#  'N(Beta)            :      123.999902694311 electrons\n',
#  'N(Total)           :      247.999805388622 electrons\n',
#  'E(XC)              :     -182.654704818737 Eh       \n',
#  'DFET-embed. en.    :        0.000000000000 Eh       \n',
#  'CPCM Solvation Model Properties:\n',
#  'Surface-charge          :           -0.01453549\n',
#  'Charge-correction       :            0.00011893 Eh               0.00324 eV\n',
#  'Free-energy (cav+disp)  :            0.00623684 Eh               0.16971 eV\n',
#  'Corrected G(solv)       :        -2208.59687899 Eh          -60098.97645 eV\n',
#  '\n',
#  '---------------\n',
#  'SCF CONVERGENCE\n',
#  '---------------\n',
#  '\n',
#  '  Last Energy change         ...    1.1613e-08  Tolerance :   1.0000e-08\n',
#  '  Last MAX-Density change    ...    1.6487e-05  Tolerance :   1.0000e-07\n',
#  '  Last RMS-Density change    ...    1.6894e-07  Tolerance :   5.0000e-09\n',
#  '  Last Orbital Gradient      ...    6.1798e-07  Tolerance :   1.0000e-05\n',
#  '  Last Orbital Rotation      ...    1.9650e-06  Tolerance :   1.0000e-05\n',
#  '\n',
#  '             **** THE GBW FILE WAS UPDATED (BCF.gbw) ****\n',
#  '             **** DENSITY FILE WAS UPDATED (BCF.scfp) ****\n',
#  '             **** ENERGY FILE WAS UPDATED (BCF.en.tmp) ****\n',
#  '             **** THE GBW FILE WAS UPDATED (BCF.gbw) ****\n',
#  '             **** DENSITY FILE WAS UPDATED (BCF.scfp) ****\n',
#  '----------------\n',
#  'ORBITAL ENERGIES\n',
#  '----------------\n',
#  '\n',
#  '  NO   OCC          E(Eh)            E(eV) \n',
#  ...]

# %%
bcf = clean_data('BCF.out')
bcfCSV = bcf.to_csv('BCF.csv')
bcf.info
# Out:
# <bound method DataFrame.info of         NO     OCC       E(Eh)      E(eV)
# 0        0  2.0000  -24.840736  -675.9508
# 1        1  2.0000  -24.840631  -675.9479
# 2        2  2.0000  -24.840480  -675.9438
# 3        3  2.0000  -24.837271  -675.8565
# 4        4  2.0000  -24.837215  -675.8550
# ...    ...     ...         ...        ...
# 1049  1049  0.0000   57.531529  1565.5125
# 1050  1050  0.0000   57.605060  1567.5134
# 1051  1051  0.0000   57.605154  1567.5159
# 1052  1052  0.0000   57.615698  1567.8028
# 1053  1053  0.0000   57.622632  1567.9915
#
# [1054 rows x 4 columns]>
